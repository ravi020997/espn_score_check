# %%
import pandas as pd

# %%
data=pd.read_excel("/Users/ravisoni/Downloads/espn cric score.xlsx",header=2)

# %%
data
# Out:
#    Records for Test Matches Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          Highest averages        NaN        NaN        NaN        NaN
# 1                    Player       Span        Mat       Inns         NO
# 2          DG Bradman (AUS)  1928-1948         52         80         10
# 3            HC Brook (ENG)  2022-2023         12         20          1
# 4            AC Voges (AUS)  2015-2016         20         31          7
# ..                      ...        ...        ...        ...        ...
# 59         KD Walters (AUS)  1965-1981         74        125         14
# 60        GC Smith (ICC/SA)  2002-2014        117        205         13
# 61        WH Ponsford (AUS)  1924-1934         29         48          4
# 62          SJ McCabe (AUS)  1930-1938         39         62          5
# 63         DR Jardine (ENG)  1928-1934         22         33          6
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# ...

# %%
clear

# %%
data.columns=data.loc[1]

# %%
data
# Out:
# 1              Player       Span  Mat  Inns   NO  Runs    HS    Ave     BF  \
# 0    Highest averages        NaN  NaN   NaN  NaN   NaN   NaN    NaN    NaN
# 1              Player       Span  Mat  Inns   NO  Runs    HS    Ave     BF
# 2    DG Bradman (AUS)  1928-1948   52    80   10  6996   334  99.94  9800+
# 3      HC Brook (ENG)  2022-2023   12    20    1  1181   186  62.15   1287
# 4      AC Voges (AUS)  2015-2016   20    31    7  1485  269*  61.87   2667
# ..                ...        ...  ...   ...  ...   ...   ...    ...    ...
# 59   KD Walters (AUS)  1965-1981   74   125   14  5357   250  48.26  8662+
# 60  GC Smith (ICC/SA)  2002-2014  117   205   13  9265   277  48.25  15525
# 61  WH Ponsford (AUS)  1924-1934   29    48    4  2122   266  48.22  3118+
# 62    SJ McCabe (AUS)  1930-1938   39    62    5  2748   232  48.21  3217+
# 63   DR Jardine (ENG)  1928-1934   22    33    6  1296   127     48  2110+
#
# 1      SR  100.0  50.0   0.0    4s   6s
# ...

# %%
data.drop([0,1])
# Out:
# 1              Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 2    DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 3      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 4      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 5     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 6     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 59   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 60  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 61  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 62    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 63   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48  2110+
#
# 1      SR  100.0  50.0   0.0    4s  6s
# 2    58.6   29.0  13.0   7.0  626+   6
# ...

# %%
data
# Out:
#      DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+  \
# 0      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 1      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# 4   H Sutcliffe (ENG)  1924-1935   54   84   9  4555   194  60.73  6558+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 56   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 57  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 58  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 59    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 60   DR Jardine (ENG)  1928-1934   22   33   6  1296   127  48.00  2110+
#
#      58.6  29  13   7  626+   6
# 0   91.76   4   7   1   141  23
# ...

# %%
data
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
data
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nf/kd7gjb6s02l017mxhtfkffl80000gn/T/ipykernel_45566/354339855.py in ?()
# ----> 1 data.unique()
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
data.columns
# Out:
# Index(['Player',   'Span',    'Mat',   'Inns',     'NO',   'Runs',     'HS',
#           'Ave',     'BF',     'SR',      100,       50,        0,     '4s',
#            '6s'],
#       dtype='object')

# %%
data.columns = ['Player',   'Span',    'Mat',   'Inns',     'NO',   'Runs',     'HS',
          'Avg',     'BF',     'SR',      100,       50,        0,     '4s',
           '6s']

# %%
data
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Avg     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
data
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Avg     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
data.isnull().any()
# Out:
# Player    False
# Span      False
# Mat       False
# Inns      False
# NO        False
# Runs      False
# HS        False
# Avg       False
# BF        False
# SR        False
# 100       False
# 50        False
# 0         False
# 4s        False
# 6s        False
# dtype: bool

# %%
data["BF"]
# Out:
# 0     9800+
# 1      1287
# 2      2667
# 3     1707+
# 4      416+
#       ...
# 57    8662+
# 58    15525
# 59    3118+
# 60    3217+
# 61    2110+
# Name: BF, Length: 62, dtype: object

# %%
data[data["BF"]=="-"]
# Out:
#                   Player       Span Mat  Inns  NO  Runs    HS    Avg BF SR  \
# 8         ED Weekes (WI)  1948-1958  48    81   5  4455   207  58.61  -  -
# 14       CL Walcott (WI)  1948-1960  44    74   7  3798   220  56.68  -  -
# 54  Hon.FS Jackson (ENG)  1893-1905  20    33   4  1415  144*  48.79  -  -
#
#     100  50  0    4s  6s
# 8    15  19  6  258+   2
# 14   15  14  1  107+  11
# 54    5   6  3   51+   0

# %%
data[["BF","SR"]]
# Out:
#        BF     SR
# 0   9800+   58.6
# 1    1287  91.76
# 2    2667  55.68
# 3   1707+  54.48
# 4    416+     56
# ..    ...    ...
# 57  8662+  49.16
# 58  15525  59.67
# 59  3118+  44.77
# 60  3217+  60.02
# 61  2110+  25.59
#
# [62 rows x 2 columns]

# %%
data["BF"].unique()
# Out:
# array(['9800+', 1287, 2667, '1707+', '416+', '6558+', '1288+', '4957+',
#        '-', '7491+', '4063+', 22882, 18100, '5363+', '2844+', 28903,
#        '178+', 17006, '665+', 1823, '13079+', '108+', '29437+', 19753,
#        '15164+', 31258, 14372, 19375, 22782, '2035+', 10636, 12436, 27395,
#        '14184+', 22461, 14349, 16077, '27002+', 3014, '9613+', '2731+',
#        22959, 20762, 16345, 7809, '488+', '619+', 10441, 2445, 15924,
#        15456, '885+', '158+', 11641, '1799+', '8662+', 15525, '3118+',
#        '3217+', '2110+'], dtype=object)

# %%
data[["BF","SR"]]=data[["BF","SR"]].replace("-","0")

# %%
data["BF"].unique()
# Out:
# array(['9800+', 1287, 2667, '1707+', '416+', '6558+', '1288+', '4957+',
#        '0', '7491+', '4063+', 22882, 18100, '5363+', '2844+', 28903,
#        '178+', 17006, '665+', 1823, '13079+', '108+', '29437+', 19753,
#        '15164+', 31258, 14372, 19375, 22782, '2035+', 10636, 12436, 27395,
#        '14184+', 22461, 14349, 16077, '27002+', 3014, '9613+', '2731+',
#        22959, 20762, 16345, 7809, '488+', '619+', 10441, 2445, 15924,
#        15456, '885+', '158+', 11641, '1799+', '8662+', 15525, '3118+',
#        '3217+', '2110+'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     object
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     object
#  7   Avg     62 non-null     float64
#  8   BF      62 non-null     object
#  9   SR      62 non-null     object
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     int64
#  13  4s      62 non-null     object
#  14  6s      62 non-null     object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 7.4+ KB

# %%
data.select_dtypes(include="object").drop(["Span","Player"],axis=1).replace("[*+]","",regex=True).astype(float).columns
# Out:
# Index(['Mat', 'HS', 'BF', 'SR', '4s', '6s'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     float64
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     float64
#  7   Avg     62 non-null     float64
#  8   BF      62 non-null     float64
#  9   SR      62 non-null     float64
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     int64
#  13  4s      62 non-null     float64
#  14  6s      62 non-null     float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 7.4+ KB

# %%
data[['Mat', 'HS', 'BF', 'SR', '4s', '6s']]=data.select_dtypes(include="object").drop(["Span","Player"],axis=1).replace("[*+]","",regex=True).astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     float64
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     float64
#  7   Avg     62 non-null     float64
#  8   BF      62 non-null     float64
#  9   SR      62 non-null     float64
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     int64
#  13  4s      62 non-null     float64
#  14  6s      62 non-null     float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 7.4+ KB

# %%
data["Span"].str.split("-")
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [1965, 1981]
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
data["Span"].str.split("-").str[0] #Starting
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 57    1965
# 58    2002
# 59    1924
# 60    1930
# 61    1928
# Name: Span, Length: 62, dtype: object

# %%
data["Start"]=data["Span"].str.split("-").str[0].astype(int)

# %%
data["End"]=data["Span"].str.split("-").str[1].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     float64
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     float64
#  7   Avg     62 non-null     float64
#  8   BF      62 non-null     float64
#  9   SR      62 non-null     float64
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     int64
#  13  4s      62 non-null     float64
#  14  6s      62 non-null     float64
#  15  Start   62 non-null     int64
#  16  End     62 non-null     int64
# dtypes: float64(7), int64(8), object(2)
# memory usage: 8.4+ KB

# %%
data
# Out:
#                Player       Span    Mat  Inns  NO  Runs     HS    Avg  \
# 0    DG Bradman (AUS)  1928-1948   52.0    80  10  6996  334.0  99.94
# 1      HC Brook (ENG)  2022-2023   12.0    20   1  1181  186.0  62.15
# 2      AC Voges (AUS)  2015-2016   20.0    31   7  1485  269.0  61.87
# 3     RG Pollock (SA)  1963-1970   23.0    41   4  2256  274.0  60.97
# 4     GA Headley (WI)  1930-1954   22.0    40   4  2190  270.0  60.83
# ..                ...        ...    ...   ...  ..   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74.0   125  14  5357  250.0  48.26
# 58  GC Smith (ICC/SA)  2002-2014  117.0   205  13  9265  277.0  48.25
# 59  WH Ponsford (AUS)  1924-1934   29.0    48   4  2122  266.0  48.22
# 60    SJ McCabe (AUS)  1930-1938   39.0    62   5  2748  232.0  48.21
# 61   DR Jardine (ENG)  1928-1934   22.0    33   6  1296  127.0  48.00
#
#          BF     SR  100  50   0      4s    6s  Start   End
# 0    9800.0  58.60   29  13   7   626.0   6.0   1928  1948
# ...

# %%
data["Span"]
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 57    1965-1981
# 58    2002-2014
# 59    1924-1934
# 60    1930-1938
# 61    1928-1934
# Name: Span, Length: 62, dtype: object

# %%
data
# Out:
#                Player       Span    Mat  Inns  NO  Runs     HS    Avg  \
# 0    DG Bradman (AUS)  1928-1948   52.0    80  10  6996  334.0  99.94
# 1      HC Brook (ENG)  2022-2023   12.0    20   1  1181  186.0  62.15
# 2      AC Voges (AUS)  2015-2016   20.0    31   7  1485  269.0  61.87
# 3     RG Pollock (SA)  1963-1970   23.0    41   4  2256  274.0  60.97
# 4     GA Headley (WI)  1930-1954   22.0    40   4  2190  270.0  60.83
# ..                ...        ...    ...   ...  ..   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74.0   125  14  5357  250.0  48.26
# 58  GC Smith (ICC/SA)  2002-2014  117.0   205  13  9265  277.0  48.25
# 59  WH Ponsford (AUS)  1924-1934   29.0    48   4  2122  266.0  48.22
# 60    SJ McCabe (AUS)  1930-1938   39.0    62   5  2748  232.0  48.21
# 61   DR Jardine (ENG)  1928-1934   22.0    33   6  1296  127.0  48.00
#
#          BF     SR  100  50   0      4s    6s  Start   End
# 0    9800.0  58.60   29  13   7   626.0   6.0   1928  1948
# ...

# %%
data.drop("Span",axis=1,inplace=True)

# %%
data["Country"]=data["Player"].str.split("(").str[1].replace(["ICC/","[)]"],"",regex=True)

# %%
data["Country"]
# Out:
# 0     AUS
# 1     ENG
# 2     AUS
# 3      SA
# 4      WI
#      ...
# 57    AUS
# 58     SA
# 59    AUS
# 60    AUS
# 61    ENG
# Name: Country, Length: 62, dtype: object

# %%
data["Player"].str.split("(").str[0]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
# 57     KD Walters
# 58       GC Smith
# 59    WH Ponsford
# 60      SJ McCabe
# 61     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
data["Player"]=data["Player"].str.split("(").str[0]

# %%
data["Player"]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
#
# 41       DCS Compton    78.0   131  15   5807  278.0  50.06   2731.0  38.81
# 42  DPMD Jayawardene   149.0   252  15  11814  374.0  49.84  22959.0  51.45
# 43           JE Root   140.0   257  21  11736  254.0  49.72  20762.0  56.52
# 44    Inzamam-ul-Haq   120.0   200  22   8830  329.0  49.60  16345.0  54.02
# 45     M Labuschagne    50.0    90   7   4114  215.0  49.56   7809.0  52.68
# 46       FMM Worrell    51.0    87   9   3860  261.0  49.48    488.0  40.16
# 47           CP Mead    17.0    26   2   1185  182.0  49.37    619.0  30.04
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   62 non-null     object
#  1   Mat      62 non-null     float64
#  2   Inns     62 non-null     int64
#  3   NO       62 non-null     int64
#  4   Runs     62 non-null     int64
#  5   HS       62 non-null     float64
#  6   Avg      62 non-null     float64
#  7   BF       62 non-null     float64
#  8   SR       62 non-null     float64
#  9   100      62 non-null     int64
#  10  50       62 non-null     int64
#  11  0        62 non-null     int64
#  12  4s       62 non-null     float64
#  13  6s       62 non-null     float64
#  14  Start    62 non-null     int64
#  15  End      62 non-null     int64
#  16  Country  62 non-null     object
# dtypes: float64(7), int64(8), object(2)
# memory usage: 8.4+ KB

# %%
data.groupby("Country").max("Mat")
# Out:
#            Mat  Inns  NO   Runs     HS    Avg       BF     SR  100  50   0  \
# Country
# AUS      168.0   287  46  13378  380.0  99.94  27002.0  60.10   41  63  22
# ENG      140.0   257  21  11736  364.0  62.15  20762.0  91.76   31  61  12
# IND      200.0   329  33  15921  319.0  54.20  31258.0  82.23   51  68  16
# NZ       100.0   176  17   8743  251.0  54.98  17006.0  53.35   32  34  11
# PAK      124.0   213  22  10099  329.0  52.57  19375.0  54.02   34  46  19
# SA       166.0   280  40  13289  278.0  60.97  28903.0  63.88   45  58  16
# SL       149.0   252  20  12400  374.0  57.40  22959.0  54.19   38  52  15
# WI       164.0   280  49  11953  400.0  60.83  27395.0  69.77   34  66  17
# ZIM       63.0   112  19   4794  232.0  51.54  10636.0  45.07   12  27   5
#
#              4s    6s  Start   End
# Country
# AUS      1509.0  82.0   2018  2024
# ENG      1280.0  44.0   2022  2024
# IND      2058.0  91.0   2011  2024
# NZ        971.0  29.0   2019  2024
# ...

# %%
data
# Out:
#                Player    Mat  Inns  NO   Runs     HS    Avg       BF     SR  \
# 0         DG Bradman    52.0    80  10   6996  334.0  99.94   9800.0  58.60
# 1           HC Brook    12.0    20   1   1181  186.0  62.15   1287.0  91.76
# 2           AC Voges    20.0    31   7   1485  269.0  61.87   2667.0  55.68
# 3         RG Pollock    23.0    41   4   2256  274.0  60.97   1707.0  54.48
# 4         GA Headley    22.0    40   4   2190  270.0  60.83    416.0  56.00
# 5        H Sutcliffe    54.0    84   9   4555  194.0  60.73   6558.0  34.59
# 6          E Paynter    20.0    31   5   1540  243.0  59.23   1288.0  45.88
# 7      KF Barrington    82.0   131  15   6806  256.0  58.67   4957.0  42.42
# 8          ED Weekes    48.0    81   5   4455  207.0  58.61      0.0   0.00
# 9         WR Hammond    85.0   140  16   7249  336.0  58.45   7491.0  38.07
# 10         GS Sobers    93.0   160  21   8032  365.0  57.78   4063.0  53.58
# ...

# %%
data.groupby("Country").count()["Player"].nlargest(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
data.to_csv("/Users/ravisoni/Documents/Pandans and Python/Pandas_Session",index=False)
